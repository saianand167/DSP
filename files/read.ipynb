# %%
file=open("a.txt","r")
print(file.read())
file.close()
# Out:
# i am raj
# i am good boy
# i am in class room

# %%
# file readline() method
file=open("a.txt","r")
print(file.readline())
file.close()
# Out:
# i am raj

# %%
# file readlines() method
file=open("a.txt","r")
print(file.readlines())	 

# those are appear as list
file.close()
# Out:
# ['i am raj\n', 'i am good boy\n', 'i am in class room']

# %%
newf=open("b.txt","r")
# error will	come because b.txt is not present
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 newf=open("b.txt","r")
#       2 # error will	come because b.txt is not present
#
# File c:\Users\saian\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'b.txt'
