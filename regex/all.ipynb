# %%
import re
text="my ph is 9014075901"
new=re.search(r"\d{10}",text) #it will find first occurence
print(new.group())
# Out:
# 9014075901

# %%
new2=re.findall(r"\d{2}",text)
print(new2)
# Out:
# ['90', '14', '07', '59', '01']
