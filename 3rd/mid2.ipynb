# %%
std={
    "st01":34,
    "sto2":78,
    "st03":55,
    "st04":90,
    "st05":61,
    "st06":47,
    "st07":88,
    "st08":29,
    "st09":73,
    "st10":66
}
import pandas as pd

# %%
s="sai"
s=s+"r"
s
# Out:
# 'sair'
