# %%
import os
print(os.getcwd())
# Out:
# c:\Users\saian\OneDrive\Desktop\dsp ay25-26\os

# %%
os.mkdir("new_dir")

# %%
print(os.listdir())
# Out:
# ['all_os.ipynb', 'new_dir']

# %%
print(os.listdir("new_dir"))
# Out:
# []

# %%
print(os.path.exists("demo.txt"))
# Out:
# False

# %%
print(os.path.isfile("e.txt"))
# Out:
# False

# %%
os.makedirs("parent_folder/child_folder")

# %%
os.remove("demo.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 os.remove("demo.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'demo.txt'
